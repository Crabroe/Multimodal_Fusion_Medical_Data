# %%
# %run Loader_ADNI_MLP.py

# %%
# %run MLP_ADNI_90_120_fMRI.py
# Out:
# in fold time: 1, epoch: 999, train_acc:1.0, test_acc->[0.73 / 0.82]<-highest_acc (epoch980))
# in time: 2, highest epoch: 980, with highest acc: 0.8181818127632141
# [[6. 1.]
#  [1. 3.]]
# in fold time: 2, epoch: 999, train_acc:1.0, test_acc->[0.45 / 0.64]<-highest_acc (epoch70))
# in time: 3, highest epoch: 70, with highest acc: 0.6363636255264282
# [[2. 1.]
#  [3. 5.]]
# in fold time: 3, epoch: 999, train_acc:1.0, test_acc->[0.64 / 0.64]<-highest_acc (epoch999))
# in time: 4, highest epoch: 999, with highest acc: 0.6363636255264282
# [[2. 1.]
#  [3. 5.]]
# in fold time: 4, epoch: 999, train_acc:1.0, test_acc->[0.55 / 0.73]<-highest_acc (epoch286))
# in time: 5, highest epoch: 286, with highest acc: 0.7272727489471436
# [[2. 3.]
#  [0. 6.]]
# in fold time: 5, epoch: 999, train_acc:1.0, test_acc->[0.64 / 0.73]<-highest_acc (epoch3))
# in time: 6, highest epoch: 3, with highest acc: 0.7272727489471436
# [[2. 3.]
#  [0. 6.]]
# ...
