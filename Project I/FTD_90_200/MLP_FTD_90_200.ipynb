# %%
# %run Loader_FTD_MLP.py

# %%
# %run MLP_FTD_fMRI_00.py
# Out:
# in fold time: 1, epoch: 999, train_acc:1.0, test_acc->[0.58 / 0.74]<-highest_acc (epoch1))
# in time: 2, highest epoch: 1, with highest acc: 0.7368420958518982
# [[ 3.  3.]
#  [ 2. 11.]]
# in fold time: 2, epoch: 999, train_acc:1.0, test_acc->[0.78 / 0.83]<-highest_acc (epoch998))
# in time: 3, highest epoch: 998, with highest acc: 0.8333333134651184
# [[9. 1.]
#  [2. 6.]]
# in fold time: 3, epoch: 999, train_acc:1.0, test_acc->[0.67 / 0.78]<-highest_acc (epoch221))
# in time: 4, highest epoch: 221, with highest acc: 0.7777777910232544
# [[5. 4.]
#  [0. 9.]]
# in fold time: 4, epoch: 999, train_acc:1.0, test_acc->[0.67 / 0.78]<-highest_acc (epoch118))
# in time: 5, highest epoch: 118, with highest acc: 0.7777777910232544
# [[7. 2.]
#  [2. 7.]]
# in fold time: 5, epoch: 999, train_acc:1.0, test_acc->[0.5 / 0.72]<-highest_acc (epoch129)))
# in time: 6, highest epoch: 129, with highest acc: 0.7222222089767456
# [[9. 3.]
#  [2. 4.]]
# ...
