# %%
# %run Loader_OCD_RNN.py

# %%
# %run rnn_OCD_fMRI_00.py
# Out:
# in epoch 0, test acc = 0.1818181872367859 / 0(epoch:0)
#  [[2. 0.]
#  [9. 0.]]
# in epoch 1, test acc = 0.1818181872367859 / 0.1818181872367859(epoch:0)
#  [[2. 0.]
#  [9. 0.]]
# in epoch 2, test acc = 0.1818181872367859 / 0.1818181872367859(epoch:1)
#  [[2. 0.]
#  [9. 0.]]
# in epoch 3, test acc = 0.1818181872367859 / 0.1818181872367859(epoch:2)
#  [[2. 0.]
#  [9. 0.]]
# in epoch 4, test acc = 0.1818181872367859 / 0.1818181872367859(epoch:3)
#  [[2. 0.]
#  [9. 0.]]
# in epoch 5, test acc = 0.3636363744735718 / 0.1818181872367859(epoch:4)
#  [[2. 0.]
#  [7. 2.]]
# in epoch 6, test acc = 0.4545454680919647 / 0.3636363744735718(epoch:5)
#  [[0. 2.]
#  [4. 5.]]
# in epoch 7, test acc = 0.5454545617103577 / 0.4545454680919647(epoch:6)
#  [[0. 2.]
#  [3. 6.]]
# in epoch 8, test acc = 0.5454545617103577 / 0.5454545617103577(epoch:7)
#  [[0. 2.]
#  [3. 6.]]
# in epoch 9, test acc = 0.4545454680919647 / 0.5454545617103577(epoch:8)
#  [[0. 2.]
#  [4. 5.]]
# ...
